# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
fi_df = pd.read_csv('../../fi/fi_M009_0908_1412_0.9221.csv')

# %%
MODEL_NUMBER = 'M009'

# %%
sns.set(style="whitegrid")
sns.set_color_codes("pastel")
plt.figure(figsize=(12, 35))
ax = sns.barplot(x='importance',
            y='feature',
            data=fi_df.sort_values('importance', ascending=False),
            color="b")
ax.set_title(f'Type {MODEL_NUMBER}')

plt.show()

# %%
low_importance = fi_df.groupby('feature')[['importance']].mean().sort_values('importance').query('importance <= 0.1').index

# %%
low_importance
# Out:
# Index(['M_sum', 'D9_fixed', 'id_30_device_fq_enc', 'id_30_fq_enc',
#        'addr2_fq_enc', 'id_27', 'id_30_device', 'id_26',
#        'ProductCD_target_mean', 'id_32', 'id_30_version_fq_enc', 'C3', 'id_22',
#        'id_21', 'id_33_fq_enc', 'card3_TransactionAmt_std', 'id_24',
#        'DeviceInfo_version_fq_enc', 'id_23', 'card3_TransactionAmt_mean',
#        'addr2', 'C10', 'C3_fq_enc', 'M1', 'TransactionAmt_check', 'C10_fq_enc',
#        'DeviceInfo_fq_enc', 'D6', 'id_29', 'C4', 'D7', 'id_35',
#        'id_30_version', 'id_25', 'id_34', 'R_emaildomain_fq_enc', 'C4_fq_enc',
#        'D9', 'D7_fq_enc', 'DT_W', 'id_28'],
#       dtype='object', name='feature')
