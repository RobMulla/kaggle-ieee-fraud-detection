# %%
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline
pd.set_option('max_columns', 100)

# %%
train = pd.read_parquet('../../input/train.parquet')
test = pd.read_parquet('../../input/test.parquet')

# %%
test.head()
# Out:
#                TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# TransactionID
# 3663549             18403224           31.95         W  10409  111.0  150.0
# 3663550             18403263           49.00         W   4272  111.0  150.0
# 3663551             18403310          171.00         W   4476  574.0  150.0
# 3663552             18403310          284.95         W  10989  360.0  150.0
# 3663553             18403317           67.95         W  18018  452.0  150.0
#
#                     card4  card5  card6  addr1  ...  id_31  id_32  id_33  \
# TransactionID                                   ...
# 3663549              visa  226.0  debit  170.0  ...   None    NaN   None
# 3663550              visa  226.0  debit  299.0  ...   None    NaN   None
# 3663551              visa  226.0  debit  472.0  ...   None    NaN   None
# 3663552              visa  166.0  debit  205.0  ...   None    NaN   None
# 3663553        mastercard  117.0  debit  264.0  ...   None    NaN   None
#
# ...

# %%
train.set_index('TransactionDT')['D1'].plot(figsize=(15, 5), style='.')

# %%
test.set_index('TransactionDT')['D4'].plot(figsize=(15, 5), style='.')
plt.show()

# %%
test.head()
# Out:
#                TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# TransactionID
# 3663549             18403224           31.95         W  10409  111.0  150.0
# 3663550             18403263           49.00         W   4272  111.0  150.0
# 3663551             18403310          171.00         W   4476  574.0  150.0
# 3663552             18403310          284.95         W  10989  360.0  150.0
# 3663553             18403317           67.95         W  18018  452.0  150.0
#
#                     card4  card5  card6  addr1  ...  id_31  id_32  id_33  \
# TransactionID                                   ...
# 3663549              visa  226.0  debit  170.0  ...   None    NaN   None
# 3663550              visa  226.0  debit  299.0  ...   None    NaN   None
# 3663551              visa  226.0  debit  472.0  ...   None    NaN   None
# 3663552              visa  166.0  debit  205.0  ...   None    NaN   None
# 3663553        mastercard  117.0  debit  264.0  ...   None    NaN   None
#
# ...

# %%
tt = pd.concat([train, test], axis=0, sort=False)

# %%
tt.shape
# Out:
# (1097231, 433)

# %%
train.shape
# Out:
# (590540, 433)

# %%
for i, d in tt.groupby('ProductCD'):
    d.set_index('TransactionDT')['D5'].plot(figsize=(15, 3), style='.', title=f'{i} - D5', alpha=0.05)
    #plt.show()

# %%
for i, d in tt.groupby('ProductCD'):
    d.set_index('TransactionDT')['D6'].plot(figsize=(15, 3), style='.', title=f'{i} - D5', alpha=0.05)
    #plt.show()

# %%
tt.query('TransactionID == 3663549')
# Out:
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 3663549            NaN       18403224           31.95         W  10409  111.0
#
#                card3 card4  card5  card6  addr1  addr2  dist1  dist2  \
# TransactionID
# 3663549        150.0  visa  226.0  debit  170.0   87.0    1.0    NaN
#
#               P_emaildomain R_emaildomain   C1   C2   C3   C4   C5   C6   C7  \
# TransactionID
# 3663549           gmail.com          None  6.0  6.0  0.0  0.0  3.0  4.0  0.0
#
#                 C8   C9  C10  C11  C12    C13  C14     D1     D2    D3     D4  \
# TransactionID
# 3663549        0.0  6.0  0.0  5.0  1.0  115.0  6.0  419.0  419.0  27.0  398.0
#
#                  D5  D6  D7  D8  D9    D10    D11  D12  D13  D14    D15 M1 M2  \
# TransactionID
# 3663549        27.0 NaN NaN NaN NaN  418.0  203.0  NaN  NaN  NaN  409.0  T  T
#
#               M3    M4    M5  ... V330 V331 V332 V333  V334  V335  V336  V337  \
# ...

# %%
tt.query('TransactionID == 3500386')
# Out:
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 3500386            0.0       13447581           47.95         W  10409  111.0
#
#                card3 card4  card5  card6  addr1  addr2  dist1  dist2  \
# TransactionID
# 3500386        150.0  visa  226.0  debit  170.0   87.0    1.0    NaN
#
#               P_emaildomain R_emaildomain   C1   C2   C3   C4   C5   C6   C7  \
# TransactionID
# 3500386           gmail.com          None  7.0  7.0  0.0  0.0  3.0  4.0  0.0
#
#                 C8   C9  C10  C11  C12    C13  C14     D1     D2    D3     D4  \
# TransactionID
# 3500386        0.0  7.0  0.0  7.0  1.0  106.0  7.0  361.0  361.0  12.0  341.0
#
#                  D5  D6  D7  D8  D9    D10    D11  D12  D13  D14   D15 M1 M2  \
# TransactionID
# 3500386        12.0 NaN NaN NaN NaN  361.0  146.0  NaN  NaN  NaN  83.0  T  T
#
#               M3    M4    M5  ... V330 V331 V332 V333  V334  V335  V336  V337  \
# ...

# %%
tt.sort_index().head()
# Out:
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 2987000            0.0          86400            68.5         W  13926    NaN
# 2987001            0.0          86401            29.0         W   2755  404.0
# 2987002            0.0          86469            59.0         W   4663  490.0
# 2987003            0.0          86499            50.0         W  18132  567.0
# 2987004            0.0          86506            50.0         H   4497  514.0
#
#                card3       card4  card5   card6  addr1  addr2  dist1  dist2  \
# TransactionID
# 2987000        150.0    discover  142.0  credit  315.0   87.0   19.0    NaN
# 2987001        150.0  mastercard  102.0  credit  325.0   87.0    NaN    NaN
# 2987002        150.0        visa  166.0   debit  330.0   87.0  287.0    NaN
# 2987003        150.0  mastercard  117.0   debit  476.0   87.0    NaN    NaN
# 2987004        150.0  mastercard  102.0  credit  420.0   87.0    NaN    NaN
#
# ...

# %%
m = 1/86400 # Slope
x1 = 86400 # The leftmost x-point
for d in range(1, 15):
    tt[f'D{d}_intercept'] = tt[f'D{d}'] + m * (x1 - tt['TransactionDT'])
    tt[f'D{d}_intercept'] = tt[f'D{d}_intercept'].round(2)

# %%
for i, d in tt.groupby('ProductCD'):
    d.set_index('TransactionDT')['D6_intercept'].plot(figsize=(15, 3), style='.', title=f'{i} - D5', alpha=0.05)
    #plt.show()

# %%
tt.groupby('D6_intercept')['TransactionDT'].count().sort_values(ascending=False).plot(kind='hist', bins=100)

# %%
tt.groupby('D4_intercept')['TransactionDT'].count().sort_values(ascending=False).plot(kind='hist', bins=50)

# %%
tt.groupby('D3_intercept')['TransactionDT'].count().sort_values(ascending=False).plot(kind='hist', bins=40)

# %%
tt.groupby('D5_intercept')['TransactionDT'].count().sort_values(ascending=False).plot(kind='hist', bins=30)

# %%
tt.groupby('D1_intercept')['TransactionDT'].count().sort_values(ascending=False).plot(kind='hist', bins=30)

# %%
tt.groupby('D4_intercept')['TransactionDT'].count().sort_values(ascending=False).plot(kind='hist', bins=30)

# %%
tt
# Out:
#                isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  \
# TransactionID
# 2987000            0.0          86400            68.5         W  13926    NaN
# 2987001            0.0          86401            29.0         W   2755  404.0
# 2987002            0.0          86469            59.0         W   4663  490.0
# 2987003            0.0          86499            50.0         W  18132  567.0
# 2987004            0.0          86506            50.0         H   4497  514.0
#
#                card3       card4  card5   card6  addr1  addr2  dist1  dist2  \
# TransactionID
# 2987000        150.0    discover  142.0  credit  315.0   87.0   19.0    NaN
# 2987001        150.0  mastercard  102.0  credit  325.0   87.0    NaN    NaN
# 2987002        150.0        visa  166.0   debit  330.0   87.0  287.0    NaN
# 2987003        150.0  mastercard  117.0   debit  476.0   87.0    NaN    NaN
# 2987004        150.0  mastercard  102.0  credit  420.0   87.0    NaN    NaN
#
# ...
